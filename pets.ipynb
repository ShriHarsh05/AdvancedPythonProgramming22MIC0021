# %% [markdown]
# # NAME: SHRIHARSH S KOTECHA
# # REGNO: 22MIC0021
# # LAB NO: 7 FILE 2

# %%
def describe_my_pet(pet_name, animal_type='dog'):
    print(f"I have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

# %%
def print_hello():
    print('Hello there')
