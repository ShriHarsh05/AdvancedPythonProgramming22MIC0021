# %%
print("hello'ji'hello")
# Out:
# hello'ji'hello

# %%
print('''Hi there "birathere"''')
# Out:
# Hi there "birathere"

# %%
print('"Technologia"')
print(' """Triple inside single"""')
# Out:
# "Technologia"
#  """Triple inside single"""

# %%
print(''' 'I said it' ''')
print(""" "Double inside Triple" """)
# Out:
#  'I said it'
#  "Double inside Triple"

# %%
print(" '''Triple inside double''' ")
# Out:
#  '''Triple inside double'''

# %%
s = 'Shriharsh'
k = 'Kotecha'
print('Hi there this is,' f'{s}{k}')
# Out:
# Hi there this is,ShriharshKotecha

# %%
# !pip install jieba
# Out:
# Collecting jieba
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 11.3 MB/s eta 0:00:00m eta 0:00:010:01:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: jieba
#   Building wheel for jieba (setup.py) ... done
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314459 sha256=43193d4a8521bd3b5967b5f27f2f642b79bfe98f39a141e6e44bba393e69190b
#   Stored in directory: /home/matlab/.cache/pip/wheels/08/a1/a3/5c8ac52cc2f5782ffffc34c95c57c8e5ecb3063dc69541ee7c
# Successfully built jieba
# Installing collected packages: jieba
# Successfully installed jieba-0.42.1

# %%
f = open('sk.txt', 'wb')
import jieba
with open('sk.txt','r',encoding='utf8') as text:
    data = text.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 import jieba
# ----> 2 with open('sk.txt','r',encoding='utf8') as text:
#       3     data = text.read()
#
# File /home/software/software/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sk.txt'

# %%
# !pip install request
# Out:
# ERROR: Could not find a version that satisfies the requirement request (from versions: none)
# ERROR: No matching distribution found for request

# %%
from urllib import request
url = "https://www.gutenberg.org/cache/epub/76503/pg76503.txt"
responce = request.urlopen(url)
raw = responce.read().decode('utf8')

# %%
# source = https://www.gutenberg.org/cache/epub/76503/pg76503.txt 
import nltk
nltk.download('punkt')
from urllib import request
from nltk.tokenize import word_tokenize

url = "https://www.gutenberg.org/cache/epub/76503/pg76503.txt"
resp = request.urlopen(url)
raw = resp.read().decode('utf8')
tokens = word_tokenize(raw)
print(type(raw))
print(len(tokens))
# Out:
# [nltk_data] Downloading package punkt to /home/matlab/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <class 'str'>
# 70822

# %%
from urllib import request
url = "https://www.gutenberg.org/cache/epub/76503/pg76503.txt"
resp = request.urlopen(url)
raw = resp.read().decode('utf8')
from nltk.tokenize import word_tokenize
tokens = word_tokenize(raw)
print(type(raw))
# Out:
# <class 'str'>
