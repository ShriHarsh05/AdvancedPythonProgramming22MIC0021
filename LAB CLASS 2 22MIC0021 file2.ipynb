# %%
# !pip install jieba
# Out:
# ...
#      ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#       --------------------------------------- 0.3/19.2 MB ? eta -:--:--
#       --------------------------------------- 0.3/19.2 MB ? eta -:--:--
#       --------------------------------------- 0.3/19.2 MB ? eta -:--:--
#       --------------------------------------- 0.3/19.2 MB ? eta -:--:--
#       --------------------------------------- 0.3/19.2 MB ? eta -:--:--
#      - ------------------------------------- 0.5/19.2 MB 236.4 kB/s eta 0:01:20
#      - ------------------------------------- 0.5/19.2 MB 236.4 kB/s eta 0:01:20
#      - ------------------------------------- 0.5/19.2 MB 236.4 kB/s eta 0:01:20
#      - ------------------------------------- 0.5/19.2 MB 236.4 kB/s eta 0:01:20
# ...

# %%
with open("a.txt", "r", encoding='utf8') as text:
    data = text.read()

# %%
data
# Out:
# '你好吗？我在这里过得很好k'

# %%
seg_list = jieba.cut(data, cut_all=False)  # precise mode
print("/ ".join(seg_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 seg_list = jieba.cut(data, cut_all=False)  # precise mode
#       2 print("/ ".join(seg_list))
#
# NameError: name 'jieba' is not defined
