# %% [markdown]
# # Lab 12
# # 22MIC0021 Shriharsh S Kotecha

# %% [markdown]
# ## Non-thread execution

# %%
import threading
import time
import random

def print_names():
    for name in ('Shriharsh', 'Mayank', 'Keshav', 'Gaurav'):
        print (name)
        time.sleep(random.uniform ( 0.5, 1.5))

def print_ages():
    for _ in range(4):
        print(random.randint(20,50))
        time.sleep(random.uniform(0.5,1.5))


print_names()
print_ages()
# Out:
# Shriharsh
# Mayank
# Keshav
# Gaurav
# 37
# 32
# 24
# 20

# %% [markdown]
# ## without join() method

# %%
import threading
import time
import random

def print_names():
    for name in ('Shriharsh', 'Mayank', 'Keshav', 'Gaurav'):
        print (name)
        time.sleep(random.uniform ( 0.5, 1.5))

def print_ages():
    for _ in range(4):
        print(random.randint(20,50))
        time.sleep(random.uniform(0.5,1.5))


t1 = threading.Thread(target = print_names)
t2 = threading.Thread(target = print_ages)

# The above threads are not doing anything yet. To do that, use start()

t1.start()
t2.start()

# t1.join()
# t2.join()
# Out:
# Shriharsh
# 34
# 42
# Mayank
# Keshav
# 37
# 42
# Gaurav

# %%
import threading
import time
import random

def print_names():
    for name in ('Shriharsh', 'Mayank', 'Keshav', 'Gaurav'):
        print (name)
        time.sleep(random.uniform ( 0.5, 1.5))

def print_ages():
    for _ in range(4):
        print(random.randint(20,50))
        time.sleep(random.uniform(0.5,1.5))


t1 = threading.Thread(target = print_names)
t2 = threading.Thread(target = print_ages)

t1.start()
t2.start()

t1.join()
t2.join()
# Out:
# Shriharsh
# 29
# 47
# Mayank
# 39
# Keshav
# Gaurav
# 30

# %%
#The execution moves between the threads when one is sleeping to the other

# %%
import threading
import requests
from pathlib import Path

def download_file(url, filename):
    print(f'Downloading {url} to {filename}')
    # Ensure parent directory exists
    Path(filename).parent.mkdir(parents=True, exist_ok=True)
    
    response = requests.get(url)
    Path(filename).write_bytes(response.content)
    print(f'Finished Downloading {filename}')

base_url = "https://www.gutenberg.org/files/8627"
urls = [
    f'{base_url}/8627-readme.txt',
    #f'{base_url}/new_file.txt',
]

threads = []
for url in urls:
    filename = "Downloads/" + url.split("/")[-1]
    t = threading.Thread(target=download_file, args=(url, filename))
    t.start()
    threads.append(t)

[t.join() for t in threads]
# Out:
# Downloading https://www.gutenberg.org/files/8627/8627-readme.txt to Downloads/8627-readme.txt
# Finished Downloading Downloads/8627-readme.txt
# [None]
